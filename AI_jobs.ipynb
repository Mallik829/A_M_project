# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Anita_Project_Datasets/AI_job/ai_job_exposure.csv')

# %%
df.head()
# Out:
#                            occupation_title soc_code  \
# 0                        Survey researchers  19-3022
# 1              Interpreters and translators  27-3091
# 2              Public relations specialists  27-3031
# 3                       Writers and authors  27-3043
# 4  Environmental scientists and specialists  19-2041
#
#                        job_category education_required  \
# 0  Life Physical And Social Science    Master's degree
# 1           Media And Communication  Bachelor's degree
# 2           Media And Communication  Bachelor's degree
# 3           Media And Communication  Bachelor's degree
# 4  Life Physical And Social Science  Bachelor's degree
#
#    median_annual_wage_usd  employment_2024  projected_growth_pct_2024_2034  \
# 0                 63380.0           8800.0                            -5.0
# 1                 59440.0          75300.0                             2.0
# 2                 69780.0         315900.0                             5.0
# ...

# %%
df['education_required'].value_counts()
# Out:
# education_required
# Bachelor's degree                    104
# High school diploma or equivalent     60
# Associate's degree                    24
# Master's degree                       22
# Postsecondary nondegree award         17
# No formal educational credential      15
# See How to Become One                 14
# Doctoral or professional degree       12
# Some college, no degree                3
# Name: count, dtype: int64

# %%
df['job_category'].value_counts()
# Out:
# job_category
# Healthcare                             39
# Architecture And Engineering           29
# Life Physical And Social Science       28
# Management                             24
# Business And Financial                 22
# Construction And Extraction            16
# Production                             11
# Installation Maintenance And Repair    10
# Media And Communication                 9
# Office And Administrative Support       9
# Education Training And Library          9
# Community And Social Service            9
# Personal Care And Service               8
# Sales                                   8
# Arts And Design                         8
# Entertainment And Sports                8
# Protective Service                      5
# Food Preparation And Serving            5
# Legal                                   4
# Transportation And Material Moving      4
# Math                                    2
# Building And Grounds Cleaning           2
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   occupation_title                271 non-null    str
#  1   soc_code                        271 non-null    str
#  2   job_category                    271 non-null    str
#  3   education_required              271 non-null    str
#  4   median_annual_wage_usd          271 non-null    float64
#  5   employment_2024                 271 non-null    float64
#  6   projected_growth_pct_2024_2034  271 non-null    float64
#  7   growth_outlook                  271 non-null    str
#  8   ai_exposure_llm_human           271 non-null    float64
#  9   ai_exposure_llm_gpt4            271 non-null    float64
#  10  ai_exposure_aioe                271 non-null    float64
#  11  ai_exposure_level               271 non-null    str
# ...
